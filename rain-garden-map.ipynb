# %% [markdown]
# # Rain Garden Map: Flushing, Queens

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import re

# %% [markdown]
# ### Data Read-In

# %%
# Read in CSV file and remove rows 0 through 2
df = pd.read_csv("GI Assets-Grid view.csv")
df = df.iloc[3:]
df.head()
# Out:
#      ID Description   Asset type               Status  \
# 3  753B         NaN  Rain Garden  Regular stewardship
# 4  760A         NaN  Rain Garden  Regular stewardship
# 5  760B         NaN  Rain Garden  Regular stewardship
# 6  764A         NaN  Rain Garden  Regular stewardship
# 7  766B         NaN  Rain Garden  Regular stewardship
#
#                                                Photo Program Area  \
# 3  753b.jpeg (https://v5.airtableusercontent.com/...       Corona
# 4  760a.jpeg (https://v5.airtableusercontent.com/...       Corona
# 5                                                NaN       Corona
# 6  764a.jpeg (https://v5.airtableusercontent.com/...       Corona
# 7  766b.jpeg (https://v5.airtableusercontent.com/...       Corona
#
#              Coordinates Record link  \
# 3  40°44'45"N 73°52'05"W         NaN
# 4  40°44'46"N 73°51'59"W         NaN
# 5  40°44'46"N 73°51'59"W         NaN
# 6  40°44'49"N 73°52'05"W         NaN
# 7  40°44'48"N 73°52'06"W         NaN
#
#                                          Stewardship Associated partner  \
# 3                753B on Fri 12/05,753B on Fri 10/24               CASA
# 4  760A on Fri 11/14,760A on Fri 12/05,760A on Fr...               CASA
# 5                                  760B on Fri 12/05               CASA
# 6                764A on Fri 12/05,764A on Fri 10/24               CASA
# 7                766B on Fri 12/05,766B on Fri 10/24               CASA
#
#    Garden Stewardship copy
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN

# %%
def dms_to_dd(dms):
    # Match DMS like 40°44'45"N or 73°52'05"W
    match = re.match(r"""(\d+)°(\d+)'([\d.]+)"([NSEW])""", dms)
    deg, minute, sec, direction = match.groups()
    dd = float(deg) + float(minute)/60 + float(sec)/3600
    if direction in ["S", "W"]:
        dd *= -1
    return dd

# Convert DMS to decimal degrees
# Split coordinate column
coords = df["Coordinates"].str.split(" ", expand=True)
df["lat"] = coords[0].apply(dms_to_dd)
df["lon"] = coords[1].apply(dms_to_dd)

# Drop empty columns
df = df.replace(r"^\s*$", pd.NA, regex=True)
df = df.dropna(axis=1, how="all")

# Create geometry
gdf = gpd.GeoDataFrame(
    df,
    geometry=[Point(xy) for xy in zip(df.lon, df.lat)],
    crs="EPSG:4326"
)

# Export
gdf.to_file("rain_gardens.geojson", driver="GeoJSON")
